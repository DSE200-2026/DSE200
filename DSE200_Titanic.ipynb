# %% [markdown]
# # Titanic
#
# Load the dataset and explore it. Add your own cells below.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/DSE200-2026/DSE200/main/titanic.csv"
df = pd.read_csv(url)
df.head()
